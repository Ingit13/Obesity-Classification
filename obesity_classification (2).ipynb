# %% [markdown]
# ## Project Objective
# To develop a machine learning classification model to predict weight categories (obesity, normal weight,overweight, and insufficient weight) using relevant demographic, lifestyle, and health-related factors. This model is aimed at helping healthcare providers and policymakers better understand weight-related risk factors, enabling targeted interventions.
#
# # Business Objectives
# **Health Risk Assessment:** Classify individuals into weight categories based on predictor variables, enabling early intervention for those at risk of obesity or insufficient weight.
#
# **Targeted Wellness Programs:** Support the design of health initiatives by identifying high-risk groups and tailoring wellness programs accordingly.
# Personalized Preventative Measures: Provide personalized recommendations to individuals based on their classification to promote healthier habits and reduce long-term health risks.
#
# **Public Health Policy:** Offer data-driven insights to assist in shaping public health policies focused on promoting balanced nutrition and physical activity.
#
# **Technical Objective**
# To develop a classification model utilizing the following predictors:
#
#
#
# *   Demographics: Age, Height, Weight
# *   Diet and Lifestyle: Eat_Vegetables, Meal_count, Smoking_Habit, Water_intake, Calorie_Monitoring
# *   Physical Activity and Behavior: Physical_activity_freq, Screen_Time_Duration, Travel_Mode
# *  Obesity_level: Target variable indicating obesity, overweight, or insufficient weight category
#
#
#
#  The model's performance was evaluated using the F1-score to balance precision and recall, given the importance of accurate classification in each weight category.

# %% [markdown]
# ## Importing necessary libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Loading the dataset

# %%
#df=pd.read_csv('/content/drive/MyDrive/datasets for python/ObesityDataSet_raw_and_data_sinthetic.csv')

url="https://raw.githubusercontent.com/Ingit13/Obesity-Classification/main/ObesityDataSet_raw_and_data_sinthetic.csv"
df = pd.read_csv(url)
df = df.rename(columns={'FAVC': 'High_Caloric', 'FCVC': 'Eat_Vegetables','NCP':'Meal_count','CAEC':'Snack_Frequency','SMOKE':
                        "Smoking_Habit",'CH2O':"Water_intake",'SCC':'Calorie_Monitoring'
                        ,'FAF':'physical_activity_freq',
                        'TUE':'Screen_Time_Duration',
                        'CALC':'Alcohol_Usage','MTRANS':'Travel_Mode','NObeyesdad':'Obesity_level'})

# %% [markdown]
# ##Defining the Variables
#
# # * The dataset contains information on insurance claims and related factors
#
# Here's an overview:
#
# 1.FAVC(High_calroic):Do you eat high caloric food frequently?
#
# 2.FCVC(Eat_Vegetables):Do you usually eat vegetables in your meals?
#
# 3.NCP(Meal Count):How many main meals do you have daily?
#
# 4.CAEC('Snack_Frequency):Do you eat any food between meals?
#
# 5.SMOKE(Smoking_Habit):Do you smoke?
#
# 6.CH20(Water_intake):How much water do you drink daily?
#
# 7.SCC(Calorie_Monitoring):Do you monitor the calories you eat daily?
#
# 8.FAF(physical_activity_freq):How often do you have physical activity?
#
# 9.TUE(Screen_Time_Duration):How much time do you use technological devices such as cell phone, videogames, television, computer and others?
#
# 10.CALC(Alcohol_Usage):How often do you drink alcohol?
#
# 11.MTRANS(Travel_Mode):Which transportation do you usually use?
#
# 12.NObeysdad(Obesity_level):	Obesity level

# %%
df.head(10)
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight High_Caloric  \
# 0  Female  21.0    1.62    64.0                            yes           no
# 1  Female  21.0    1.52    56.0                            yes           no
# 2    Male  23.0    1.80    77.0                            yes           no
# 3    Male  27.0    1.80    87.0                             no           no
# 4    Male  22.0    1.78    89.8                             no           no
# 5    Male  29.0    1.62    53.0                             no          yes
# 6  Female  23.0    1.50    55.0                            yes          yes
# 7    Male  22.0    1.64    53.0                             no           no
# 8    Male  24.0    1.78    64.0                            yes          yes
# 9    Male  22.0    1.72    68.0                            yes          yes
#
#    Eat_Vegetables  Meal_count Snack_Frequency Smoking_Habit  Water_intake  \
# 0             2.0         3.0       Sometimes            no           2.0
# 1             3.0         3.0       Sometimes           yes           3.0
# 2             2.0         3.0       Sometimes            no           2.0
# 3             3.0         3.0       Sometimes            no           2.0
# 4             2.0         1.0       Sometimes            no           2.0
# 5             2.0         3.0       Sometimes            no           2.0
# 6             3.0         3.0       Sometimes            no           2.0
# 7             2.0         3.0       Sometimes            no           2.0
# 8             3.0         3.0       Sometimes            no           2.0
# 9             2.0         3.0       Sometimes            no           2.0
#
#   Calorie_Monitoring  physical_activity_freq  Screen_Time_Duration  \
# 0                 no                     0.0                   1.0
# 1                yes                     3.0                   0.0
# 2                 no                     2.0                   1.0
# 3                 no                     2.0                   0.0
# 4                 no                     0.0                   0.0
# 5                 no                     0.0                   0.0
# 6                 no                     1.0                   0.0
# 7                 no                     3.0                   0.0
# 8                 no                     1.0                   1.0
# 9                 no                     1.0                   1.0
#
#   Alcohol_Usage            Travel_Mode        Obesity_level
# 0            no  Public_Transportation        Normal_Weight
# 1     Sometimes  Public_Transportation        Normal_Weight
# 2    Frequently  Public_Transportation        Normal_Weight
# 3    Frequently                Walking   Overweight_Level_I
# 4     Sometimes  Public_Transportation  Overweight_Level_II
# 5     Sometimes             Automobile        Normal_Weight
# 6     Sometimes              Motorbike        Normal_Weight
# 7     Sometimes  Public_Transportation        Normal_Weight
# 8    Frequently  Public_Transportation        Normal_Weight
# 9            no  Public_Transportation        Normal_Weight

# %%
df.sample(5)
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 1341    Male  21.016665  1.790172  105.042194                            yes
# 1262    Male  22.277859  1.947406  116.893105                            yes
# 848     Male  19.337404  1.859927   87.105828                            yes
# 611   Female  22.209706  1.593847   44.050251                             no
# 1701    Male  33.789301  1.681100  102.523111                            yes
#
#      High_Caloric  Eat_Vegetables  Meal_count Snack_Frequency Smoking_Habit  \
# 1341          yes        2.259679    3.000000       Sometimes            no
# 1262          yes        2.000000    3.000000       Sometimes            no
# 848           yes        2.212320    4.000000       Sometimes            no
# 611            no        3.000000    2.993210      Frequently            no
# 1701          yes        2.813775    2.372705       Sometimes            no
#
#       Water_intake Calorie_Monitoring  physical_activity_freq  \
# 1341      1.026143                 no                0.268801
# 1262      3.000000                 no                0.975187
# 848       2.374044                 no                2.000000
# 611       2.702783                 no                1.967234
# 1701      1.000000                 no                1.979355
#
#       Screen_Time_Duration Alcohol_Usage            Travel_Mode  \
# 1341              0.077818     Sometimes  Public_Transportation
# 1262              1.000000     Sometimes  Public_Transportation
# 848               0.622638     Sometimes  Public_Transportation
# 611               0.000000            no  Public_Transportation
# 1701              0.000000            no  Public_Transportation
#
#             Obesity_level
# 1341       Obesity_Type_I
# 1262       Obesity_Type_I
# 848    Overweight_Level_I
# 611   Insufficient_Weight
# 1701      Obesity_Type_II

# %% [markdown]
# ## Basic Checks

# %%
df.shape
# Out:
# (2111, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   float64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   object
#  5   High_Caloric                    2111 non-null   object
#  6   Eat_Vegetables                  2111 non-null   float64
#  7   Meal_count                      2111 non-null   float64
#  8   Snack_Frequency                 2111 non-null   object
#  9   Smoking_Habit                   2111 non-null   object
#  10  Water_intake                    2111 non-null   float64
#  11  Calorie_Monitoring              2111 non-null   object
#  12  physical_activity_freq          2111 non-null   float64
#  13  Screen_Time_Duration            2111 non-null   float64
#  14  Alcohol_Usage                   2111 non-null   object
#  15  Travel_Mode                     2111 non-null   object
#  16  Obesity_level                   2111 non-null   object
# dtypes: float64(8), object(9)
# memory usage: 280.5+ KB

# %%
df.describe()
# Out:
#                Age       Height       Weight  Eat_Vegetables   Meal_count  \
# count  2111.000000  2111.000000  2111.000000     2111.000000  2111.000000
# mean     24.312600     1.701677    86.586058        2.419043     2.685628
# std       6.345968     0.093305    26.191172        0.533927     0.778039
# min      14.000000     1.450000    39.000000        1.000000     1.000000
# 25%      19.947192     1.630000    65.473343        2.000000     2.658738
# 50%      22.777890     1.700499    83.000000        2.385502     3.000000
# 75%      26.000000     1.768464   107.430682        3.000000     3.000000
# max      61.000000     1.980000   173.000000        3.000000     4.000000
#
#        Water_intake  physical_activity_freq  Screen_Time_Duration
# count   2111.000000             2111.000000           2111.000000
# mean       2.008011                1.010298              0.657866
# std        0.612953                0.850592              0.608927
# min        1.000000                0.000000              0.000000
# 25%        1.584812                0.124505              0.000000
# 50%        2.000000                1.000000              0.625350
# 75%        2.477420                1.666678              1.000000
# max        3.000000                3.000000              2.000000

# %%
df.nunique()
# Out:
# Gender                               2
# Age                               1402
# Height                            1574
# Weight                            1525
# family_history_with_overweight       2
# High_Caloric                         2
# Eat_Vegetables                     810
# Meal_count                         635
# Snack_Frequency                      4
# Smoking_Habit                        2
# Water_intake                      1268
# Calorie_Monitoring                   2
# physical_activity_freq            1190
# Screen_Time_Duration              1129
# Alcohol_Usage                        4
# Travel_Mode                          5
# Obesity_level                        7
# dtype: int64

# %% [markdown]
# ## Data Preprocessing

# %%
df.isnull().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# High_Caloric                      0
# Eat_Vegetables                    0
# Meal_count                        0
# Snack_Frequency                   0
# Smoking_Habit                     0
# Water_intake                      0
# Calorie_Monitoring                0
# physical_activity_freq            0
# Screen_Time_Duration              0
# Alcohol_Usage                     0
# Travel_Mode                       0
# Obesity_level                     0
# dtype: int64

# %% [markdown]
# No null values found in  the datset

# %%
#creating a copy of the dataframe
df1=df.copy()

# %%
#df['Meal_count']=df['Meal_count'].astype(int)

# %% [markdown]
# # Checking all the numerical and categotrical columns

# %%
#all_columns
print("all columms=",df1.columns)
print('--------------------------------')
print('categorial_columns=',df1.select_dtypes(include='object').columns)
print('--------------------------------')
print('numerical columns=',df1.select_dtypes(include='number').columns)
# Out:
# all columms= Index(['Gender', 'Age', 'Height', 'Weight', 'family_history_with_overweight',
#        'High_Caloric', 'Eat_Vegetables', 'Meal_count', 'Snack_Frequency',
#        'Smoking_Habit', 'Water_intake', 'Calorie_Monitoring',
#        'physical_activity_freq', 'Screen_Time_Duration', 'Alcohol_Usage',
#        'Travel_Mode', 'Obesity_level'],
#       dtype='object')
# --------------------------------
# categorial_columns= Index(['Gender', 'family_history_with_overweight', 'High_Caloric',
#        'Snack_Frequency', 'Smoking_Habit', 'Calorie_Monitoring',
#        'Alcohol_Usage', 'Travel_Mode', 'Obesity_level'],
#       dtype='object')
# --------------------------------
# numerical columns= Index(['Age', 'Height', 'Weight', 'Eat_Vegetables', 'Meal_count',
#        'Water_intake', 'physical_activity_freq', 'Screen_Time_Duration'],
#       dtype='object')

# %%
#categorical column dataframe
df_cat=df1.select_dtypes(include='object')
df_cat.head()
# Out:
#    Gender family_history_with_overweight High_Caloric Snack_Frequency  \
# 0  Female                            yes           no       Sometimes
# 1  Female                            yes           no       Sometimes
# 2    Male                            yes           no       Sometimes
# 3    Male                             no           no       Sometimes
# 4    Male                             no           no       Sometimes
#
#   Smoking_Habit Calorie_Monitoring Alcohol_Usage            Travel_Mode  \
# 0            no                 no            no  Public_Transportation
# 1           yes                yes     Sometimes  Public_Transportation
# 2            no                 no    Frequently  Public_Transportation
# 3            no                 no    Frequently                Walking
# 4            no                 no     Sometimes  Public_Transportation
#
#          Obesity_level
# 0        Normal_Weight
# 1        Normal_Weight
# 2        Normal_Weight
# 3   Overweight_Level_I
# 4  Overweight_Level_II

# %%
numeric_cols=df1.select_dtypes(include='number').columns
numeric_cols
# Out:
# Index(['Age', 'Height', 'Weight', 'Eat_Vegetables', 'Meal_count',
#        'Water_intake', 'physical_activity_freq', 'Screen_Time_Duration'],
#       dtype='object')

# %% [markdown]
# ## Checking for Outliers

# %%
fig, axes = plt.subplots(1, len(numeric_cols), figsize=(15, 5))  # Adjust figsize as needed

for i, col in enumerate(numeric_cols):
  sns.boxplot(ax=axes[i], y=df1[col])
  axes[i].set_title(col)

plt.tight_layout()  # Adjust spacing between subplots
plt.show()

# %% [markdown]
# This series of boxplots for different variables in the insurance dataset, providing a visual summary of the distribution, central tendency, and variability of the data, as well as highlighting any potential outliers. Here’s a breakdown of each plot:
# 1. Age:The median age is arround 23 and the max age is around 35 and min weight is 20.This columnn have significant outliers
# 2. Height: The range lies from 16.5 to 17.5 metres with no outliers.
# 3. weight : similarily the weight column have the following range in the box plot with a one outlier.
# 4. Meal count: This column have significant level of outliers as we can see in both the extreme quantile
# 5.water_intake: NO outliers
# 6.Physical activity_freq: NO outliers
# 7.Screem time duration:NO outliers

# %% [markdown]
# ## Removing outliers using the IQR method

# %%
Q1 = df1[numeric_cols].quantile(0.25)
Q3 = df1[numeric_cols].quantile(0.75)

IQR = Q3 - Q1

print(IQR)
# Out:
# Age                        6.052808
# Height                     0.138464
# Weight                    41.957339
# Eat_Vegetables             1.000000
# Meal_count                 0.341262
# Water_intake               0.892607
# physical_activity_freq     1.542172
# Screen_Time_Duration       1.000000
# dtype: float64

# %%
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
#making a separte outliers that dont contain any outliers

df1_no_outliers = df1[~((df1[numeric_cols] < lower_bound) | (df1[numeric_cols] > upper_bound)).any(axis=1)]

# %%
df1_no_outliers.head()
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight High_Caloric  \
# 0  Female  21.0    1.62    64.0                            yes           no
# 1  Female  21.0    1.52    56.0                            yes           no
# 2    Male  23.0    1.80    77.0                            yes           no
# 3    Male  27.0    1.80    87.0                             no           no
# 5    Male  29.0    1.62    53.0                             no          yes
#
#    Eat_Vegetables  Meal_count Snack_Frequency Smoking_Habit  Water_intake  \
# 0             2.0         3.0       Sometimes            no           2.0
# 1             3.0         3.0       Sometimes           yes           3.0
# 2             2.0         3.0       Sometimes            no           2.0
# 3             3.0         3.0       Sometimes            no           2.0
# 5             2.0         3.0       Sometimes            no           2.0
#
#   Calorie_Monitoring  physical_activity_freq  Screen_Time_Duration  \
# 0                 no                     0.0                   1.0
# 1                yes                     3.0                   0.0
# 2                 no                     2.0                   1.0
# 3                 no                     2.0                   0.0
# 5                 no                     0.0                   0.0
#
#   Alcohol_Usage            Travel_Mode       Obesity_level
# 0            no  Public_Transportation       Normal_Weight
# 1     Sometimes  Public_Transportation       Normal_Weight
# 2    Frequently  Public_Transportation       Normal_Weight
# 3    Frequently                Walking  Overweight_Level_I
# 5     Sometimes             Automobile       Normal_Weight

# %% [markdown]
# ## Basic checks on the outlier frame dataframe

# %%
df1_no_outliers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1409 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          1409 non-null   object
#  1   Age                             1409 non-null   float64
#  2   Height                          1409 non-null   float64
#  3   Weight                          1409 non-null   float64
#  4   family_history_with_overweight  1409 non-null   object
#  5   High_Caloric                    1409 non-null   object
#  6   Eat_Vegetables                  1409 non-null   float64
#  7   Meal_count                      1409 non-null   float64
#  8   Snack_Frequency                 1409 non-null   object
#  9   Smoking_Habit                   1409 non-null   object
#  10  Water_intake                    1409 non-null   float64
#  11  Calorie_Monitoring              1409 non-null   object
#  12  physical_activity_freq          1409 non-null   float64
#  13  Screen_Time_Duration            1409 non-null   float64
#  14  Alcohol_Usage                   1409 non-null   object
#  15  Travel_Mode                     1409 non-null   object
#  16  Obesity_level                   1409 non-null   object
# dtypes: float64(8), object(9)
# memory usage: 198.1+ KB

# %% [markdown]
# ## Feature Engineering

# %%
numerical_data=df1_no_outliers.select_dtypes(include='number')
numerical_data.head()
# Out:
#     Age  Height  Weight  Eat_Vegetables  Meal_count  Water_intake  \
# 0  21.0    1.62    64.0             2.0         3.0           2.0
# 1  21.0    1.52    56.0             3.0         3.0           3.0
# 2  23.0    1.80    77.0             2.0         3.0           2.0
# 3  27.0    1.80    87.0             3.0         3.0           2.0
# 5  29.0    1.62    53.0             2.0         3.0           2.0
#
#    physical_activity_freq  Screen_Time_Duration
# 0                     0.0                   1.0
# 1                     3.0                   0.0
# 2                     2.0                   1.0
# 3                     2.0                   0.0
# 5                     0.0                   0.0

# %% [markdown]
# ##Correlation Matrix

# %%
plt.figure(figsize=(8,8))
sns.heatmap(numerical_data.corr(),annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ##Variation Inflation Factor (VIF)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

x = numerical_data

vif_data = pd.DataFrame()

vif_data["feature"] = x.columns

vif_data["VIF"] = [variance_inflation_factor(x.values, i) for i in range(len(x.columns))]

vif_data
# Out:
#                   feature         VIF
# 0                     Age   36.250737
# 1                  Height  255.016441
# 2                  Weight   18.179144
# 3          Eat_Vegetables   22.668455
# 4              Meal_count  201.253651
# 5            Water_intake   13.674795
# 6  physical_activity_freq    2.839753
# 7    Screen_Time_Duration    2.578143

# %%
#height vif=255.016. Dropping Height
numerical_data=numerical_data.drop('Height',axis=1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

x = numerical_data

vif_data = pd.DataFrame()

vif_data["feature"] = x.columns

vif_data["VIF"] = [variance_inflation_factor(x.values, i) for i in range(len(x.columns))]

vif_data
# Out:
#                   feature        VIF
# 0                     Age  33.141861
# 1                  Weight  15.403211
# 2          Eat_Vegetables  22.554958
# 3              Meal_count  54.829553
# 4            Water_intake  13.569184
# 5  physical_activity_freq   2.618580
# 6    Screen_Time_Duration   2.539322

# %%
#dropping Meal_count  with vif=54.829553
numerical_data=numerical_data.drop('Meal_count',axis=1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

x = numerical_data

vif_data = pd.DataFrame()

vif_data["feature"] = x.columns

vif_data["VIF"] = [variance_inflation_factor(x.values, i) for i in range(len(x.columns))]

vif_data
# Out:
#                   feature        VIF
# 0                     Age  20.033128
# 1                  Weight  15.402401
# 2          Eat_Vegetables  18.032624
# 3            Water_intake  12.541722
# 4  physical_activity_freq   2.499125
# 5    Screen_Time_Duration   2.298302

# %%
#dropping Age  with vif=20.033128
numerical_data=numerical_data.drop('Age',axis=1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

x = numerical_data

vif_data = pd.DataFrame()

vif_data["feature"] = x.columns

vif_data["VIF"] = [variance_inflation_factor(x.values, i) for i in range(len(x.columns))]

vif_data
# Out:
#                   feature        VIF
# 0                  Weight  12.726871
# 1          Eat_Vegetables  14.640881
# 2            Water_intake  11.804359
# 3  physical_activity_freq   2.498881
# 4    Screen_Time_Duration   2.275589

# %%
#dropping Eat_Vegetables  with vif=14.640881
numerical_data=numerical_data.drop('Eat_Vegetables',axis=1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

x = numerical_data

vif_data = pd.DataFrame()

vif_data["feature"] = x.columns

vif_data["VIF"] = [variance_inflation_factor(x.values, i) for i in range(len(x.columns))]

vif_data
# Out:
#                   feature       VIF
# 0                  Weight  8.443129
# 1            Water_intake  9.954958
# 2  physical_activity_freq  2.451944
# 3    Screen_Time_Duration  2.235796

# %% [markdown]
# At the wnd we are left with the above numerical columns with no multicollinearity among them

# %%
numerical_data.head()
# Out:
#    Weight  Water_intake  physical_activity_freq  Screen_Time_Duration
# 0    64.0           2.0                     0.0                   1.0
# 1    56.0           3.0                     3.0                   0.0
# 2    77.0           2.0                     2.0                   1.0
# 3    87.0           2.0                     2.0                   0.0
# 5    53.0           2.0                     0.0                   0.0

# %% [markdown]
# ##Fetching the values dependent column

# %%
target=df1_no_outliers['Obesity_level']
target.head()
# Out:
# 0         Normal_Weight
# 1         Normal_Weight
# 2         Normal_Weight
# 3    Overweight_Level_I
# 5         Normal_Weight
# Name: Obesity_level, dtype: object

# %% [markdown]
# ##Categorical columns

# %%
cat_cols = df1.select_dtypes(exclude=['number'])
cat_cols
# Out:
#       Gender family_history_with_overweight High_Caloric Snack_Frequency  \
# 0     Female                            yes           no       Sometimes
# 1     Female                            yes           no       Sometimes
# 2       Male                            yes           no       Sometimes
# 3       Male                             no           no       Sometimes
# 4       Male                             no           no       Sometimes
# ...      ...                            ...          ...             ...
# 2106  Female                            yes          yes       Sometimes
# 2107  Female                            yes          yes       Sometimes
# 2108  Female                            yes          yes       Sometimes
# 2109  Female                            yes          yes       Sometimes
# 2110  Female                            yes          yes       Sometimes
#
#      Smoking_Habit Calorie_Monitoring Alcohol_Usage            Travel_Mode  \
# 0               no                 no            no  Public_Transportation
# 1              yes                yes     Sometimes  Public_Transportation
# 2               no                 no    Frequently  Public_Transportation
# 3               no                 no    Frequently                Walking
# 4               no                 no     Sometimes  Public_Transportation
# ...            ...                ...           ...                    ...
# 2106            no                 no     Sometimes  Public_Transportation
# 2107            no                 no     Sometimes  Public_Transportation
# 2108            no                 no     Sometimes  Public_Transportation
# 2109            no                 no     Sometimes  Public_Transportation
# 2110            no                 no     Sometimes  Public_Transportation
#
#             Obesity_level
# 0           Normal_Weight
# 1           Normal_Weight
# 2           Normal_Weight
# 3      Overweight_Level_I
# 4     Overweight_Level_II
# ...                   ...
# 2106     Obesity_Type_III
# 2107     Obesity_Type_III
# 2108     Obesity_Type_III
# 2109     Obesity_Type_III
# 2110     Obesity_Type_III
#
# [2111 rows x 9 columns]

# %% [markdown]
# ##Calculating Cramer's V

# %%
from scipy.stats import chi2_contingency
def cramers_v(confusion_matrix):
    chi2 = chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.values.sum()
    phi2 = chi2 / n
    r, k = confusion_matrix.shape
    phi2corr = max(0, phi2 - ((k-1)*(r-1))/(n-1))
    rcorr = r - ((r-1)**2)/(n-1)
    kcorr = k - ((k-1)**2)/(n-1)
    return np.sqrt(phi2corr / min((kcorr-1), (rcorr-1)))

# %% [markdown]
# ## Create contingency tables

# %%
gender_familyoverweight = pd.crosstab(df1_no_outliers['Gender'], df1_no_outliers['family_history_with_overweight'])
gender_highcaloric = pd.crosstab(df1_no_outliers['Gender'], df1_no_outliers['High_Caloric'])
gender_smoke = pd.crosstab(df1_no_outliers['Gender'], df1_no_outliers['Smoking_Habit'])
gender_Snack_Frequency = pd.crosstab(df1_no_outliers['Gender'], df1_no_outliers['Snack_Frequency'])
gender_Travel_Mode = pd.crosstab(df1_no_outliers['Gender'], df1_no_outliers['Travel_Mode'])
gender_Calorie_Monitoring = pd.crosstab(df1_no_outliers['Gender'], df1_no_outliers['Calorie_Monitoring'])
gender_alcohol = pd.crosstab(df1_no_outliers['Gender'], df1_no_outliers['Alcohol_Usage'])

familyoverweight_highcaloric = pd.crosstab(df1_no_outliers['family_history_with_overweight'], df1_no_outliers['High_Caloric'])
familyoverweight_smoke = pd.crosstab(df1_no_outliers['family_history_with_overweight'], df1_no_outliers['Smoking_Habit'])
familyoverweight_Snack_Frequency = pd.crosstab(df1_no_outliers['family_history_with_overweight'], df1_no_outliers['Snack_Frequency'])
familyoverweight_Travel_Mode = pd.crosstab(df1_no_outliers['family_history_with_overweight'], df1_no_outliers['Travel_Mode'])
familyoverweight_Calorie_Monitoring = pd.crosstab(df1_no_outliers['family_history_with_overweight'], df1_no_outliers['Calorie_Monitoring'])
family_overweight_alcohol = pd.crosstab(df1_no_outliers['family_history_with_overweight'], df1_no_outliers['Alcohol_Usage'])

high_caloric_snacks = pd.crosstab(df1_no_outliers['High_Caloric'], df1_no_outliers['Snack_Frequency'])
high_caloric_smoke = pd.crosstab(df1_no_outliers['High_Caloric'], df1_no_outliers['Smoking_Habit'])
high_caloric_Travel_Mode = pd.crosstab(df1_no_outliers['High_Caloric'], df1_no_outliers['Travel_Mode'])
high_caloric_Calorie_Monitoring = pd.crosstab(df1_no_outliers['High_Caloric'], df1_no_outliers['Calorie_Monitoring'])
high_caloric_alcohol = pd.crosstab(df1_no_outliers['High_Caloric'], df1_no_outliers['Alcohol_Usage'])

snacks_smoke = pd.crosstab(df1_no_outliers['Snack_Frequency'], df1_no_outliers['Smoking_Habit'])
snacks_Travel_Mode = pd.crosstab(df1_no_outliers['Snack_Frequency'], df1_no_outliers['Travel_Mode'])
snacks_Calorie_Monitoring = pd.crosstab(df1_no_outliers['Snack_Frequency'], df1_no_outliers['Calorie_Monitoring'])
snacks_alcohol = pd.crosstab(df1_no_outliers['Snack_Frequency'], df1_no_outliers['Alcohol_Usage'])

smoke_Travel_Mode = pd.crosstab(df1_no_outliers['Smoking_Habit'], df1_no_outliers['Travel_Mode'])
smoke_Calorie_Monitoring = pd.crosstab(df1_no_outliers['Smoking_Habit'], df1_no_outliers['Calorie_Monitoring'])
smoke_alcohol = pd.crosstab(df1_no_outliers['Smoking_Habit'], df1_no_outliers['Alcohol_Usage'])

calori_monitoring_alcohol=pd.crosstab(df1_no_outliers['Calorie_Monitoring'], df1_no_outliers['Alcohol_Usage'])
calori_monitoring_travel=pd.crosstab(df1_no_outliers['Calorie_Monitoring'], df1_no_outliers['Travel_Mode'])

alcohol_travel=pd.crosstab(df1_no_outliers['Alcohol_Usage'], df1_no_outliers['Travel_Mode'])

# %% [markdown]
# ## Calculate Cramer's V for each pair

# %%
cv_gender_familyoverweight = cramers_v(gender_familyoverweight)
cv_gender_highcaloric = cramers_v(gender_highcaloric)
cv_gender_smoke = cramers_v(gender_smoke)
cv_gender_Snack_Frequency = cramers_v(gender_Snack_Frequency)
cv_gender_Travel_Mode = cramers_v(gender_Travel_Mode)
cv_gender_Calorie_Monitoring = cramers_v(gender_Calorie_Monitoring)
cv_gender_alcohol = cramers_v(gender_alcohol)

cv_familyoverweight_highcaloric = cramers_v(familyoverweight_highcaloric)
cv_familyoverweight_smoke = cramers_v(familyoverweight_smoke)
cv_familyoverweight_Snack_Frequency = cramers_v(familyoverweight_Snack_Frequency)
cv_familyoverweight_Travel_Mode = cramers_v(familyoverweight_Travel_Mode)
cv_familyoverweight_Calorie_Monitoring = cramers_v(familyoverweight_Calorie_Monitoring)
cv_family_overweight_alcohol = cramers_v(family_overweight_alcohol)

cv_high_caloric_snacks = cramers_v(high_caloric_snacks)
cv_high_caloric_smoke = cramers_v(high_caloric_smoke)
cv_high_caloric_Travel_Mode = cramers_v(high_caloric_Travel_Mode)
cv_high_caloric_Calorie_Monitoring = cramers_v(high_caloric_Calorie_Monitoring)
cv_high_caloric_alcohol = cramers_v(high_caloric_alcohol)

cv_snacks_smoke = cramers_v(snacks_smoke)
cv_snacks_Travel_Mode = cramers_v(snacks_Travel_Mode)
cv_snacks_Calorie_Monitoring = cramers_v(snacks_Calorie_Monitoring)
cv_snacks_alcohol = cramers_v(snacks_alcohol)

cv_smoke_Travel_Mode = cramers_v(smoke_Travel_Mode)
cv_smoke_Calorie_Monitoring = cramers_v(smoke_Calorie_Monitoring)
cv_smoke_alcohol = cramers_v(smoke_alcohol)

cv_calori_monitoring_alcohol=cramers_v(calori_monitoring_alcohol)
cv_calori_monitoring_travel=cramers_v(calori_monitoring_travel)

cv_alcohol_travel=cramers_v(alcohol_travel)

# %% [markdown]
# # Association Matrix

# %%
def calculate_cramers_v_matrix(data, columns):
    cramers_v_matrix = pd.DataFrame(index=columns, columns=columns, dtype=float)
    for col1 in columns:
        for col2 in columns:
            if col1 != col2:
                contingency_table = pd.crosstab(df1_no_outliers[col1], df1_no_outliers[col2])
                cramers_v_matrix.loc[col1, col2] = cramers_v(contingency_table)
            else:
                cramers_v_matrix.loc[col1, col2] = 1.0
    return cramers_v_matrix

# %%
# Calculate Cramer's V matrix for the selected categorical variables
categorical_columns = df1.select_dtypes(include='object').columns
cramers_v_matrix = calculate_cramers_v_matrix(df1_no_outliers, categorical_columns)

# %%
# Visualize the association matrix with annotations
plt.figure(figsize=(8, 6))
sns.heatmap(cramers_v_matrix, annot=True, cmap='Blues', cbar=True, square=True, fmt=".2f")
plt.title("Cramer's V Association Matrix")
plt.show()

# %% [markdown]
# **1.Diagonal Values (1.00):**
#
# The values along the diagonal  are all 1.00. This is expected because a variable is perfectly associated with itself.
#
# **2.Off-diagonal Values:**
# *   Gender vs. Obesity Level: Moderate association (0.67)
# *   Family History with Overweight vs. Obesity Level: Moderate association (0.54)
#
# *  High Caloric vs. Obesity Level: Moderate association (0.35)
#
#
# *   Snack_Frequency vs Obesity Level: Moderate association (0.31)
# *   Alcohol_Usage vs Obesity Level:Moderate association (0.34)
#
#
# **Taking the  categorical columns(Snack_Frequency,Gender,Family_history_with_overweight,alcohol_usage) for further analysis**

# %% [markdown]
# # **Making a new dataframe for final modelling**

# %%
df_new=df1_no_outliers.drop(['Gender','family_history_with_overweight','High_Caloric','Snack_Frequency','Alcohol_Usage'],axis=1,inplace=True)
# Out:
# <ipython-input-42-fd66d84fb298>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new=df1_no_outliers.drop(['Gender','family_history_with_overweight','High_Caloric','Snack_Frequency','Alcohol_Usage'],axis=1,inplace=True)

# %%
df_new=df1_no_outliers.copy()

# %% [markdown]
# # Basic Check on the new dataframe created

# %%
print(df_new.shape)
print('-'*100)
print(df_new.head())
print('-'*100)
print(df_new.info())

print('-'*100)
print(df_new.isnull().sum())
# Out:
# (1409, 12)
# ----------------------------------------------------------------------------------------------------
#     Age  Height  Weight  Eat_Vegetables  Meal_count Smoking_Habit  \
# 0  21.0    1.62    64.0             2.0         3.0            no
# 1  21.0    1.52    56.0             3.0         3.0           yes
# 2  23.0    1.80    77.0             2.0         3.0            no
# 3  27.0    1.80    87.0             3.0         3.0            no
# 5  29.0    1.62    53.0             2.0         3.0            no
#
#    Water_intake Calorie_Monitoring  physical_activity_freq  \
# 0           2.0                 no                     0.0
# 1           3.0                yes                     3.0
# 2           2.0                 no                     2.0
# 3           2.0                 no                     2.0
# 5           2.0                 no                     0.0
#
#    Screen_Time_Duration            Travel_Mode       Obesity_level
# 0                   1.0  Public_Transportation       Normal_Weight
# 1                   0.0  Public_Transportation       Normal_Weight
# 2                   1.0  Public_Transportation       Normal_Weight
# 3                   0.0                Walking  Overweight_Level_I
# 5                   0.0             Automobile       Normal_Weight
# ----------------------------------------------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# Index: 1409 entries, 0 to 2110
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     1409 non-null   float64
#  1   Height                  1409 non-null   float64
#  2   Weight                  1409 non-null   float64
#  3   Eat_Vegetables          1409 non-null   float64
#  4   Meal_count              1409 non-null   float64
#  5   Smoking_Habit           1409 non-null   object
#  6   Water_intake            1409 non-null   float64
#  7   Calorie_Monitoring      1409 non-null   object
#  8   physical_activity_freq  1409 non-null   float64
#  9   Screen_Time_Duration    1409 non-null   float64
#  10  Travel_Mode             1409 non-null   object
#  11  Obesity_level           1409 non-null   object
# dtypes: float64(8), object(4)
# memory usage: 143.1+ KB
# None
# ----------------------------------------------------------------------------------------------------
# Age                       0
# Height                    0
# Weight                    0
# Eat_Vegetables            0
# Meal_count                0
# Smoking_Habit             0
# Water_intake              0
# Calorie_Monitoring        0
# physical_activity_freq    0
# Screen_Time_Duration      0
# Travel_Mode               0
# Obesity_level             0
# dtype: int64

# %%
df_new['Obesity_level'].value_counts().sort_values(ascending=False)
# Out:
# Obesity_level
# Obesity_Type_III       323
# Obesity_Type_II        220
# Normal_Weight          199
# Obesity_Type_I         197
# Overweight_Level_II    172
# Overweight_Level_I     150
# Insufficient_Weight    148
# Name: count, dtype: int64

# %%
df_new.head()
# Out:
#     Age  Height  Weight  Eat_Vegetables  Meal_count Smoking_Habit  \
# 0  21.0    1.62    64.0             2.0         3.0            no
# 1  21.0    1.52    56.0             3.0         3.0           yes
# 2  23.0    1.80    77.0             2.0         3.0            no
# 3  27.0    1.80    87.0             3.0         3.0            no
# 5  29.0    1.62    53.0             2.0         3.0            no
#
#    Water_intake Calorie_Monitoring  physical_activity_freq  \
# 0           2.0                 no                     0.0
# 1           3.0                yes                     3.0
# 2           2.0                 no                     2.0
# 3           2.0                 no                     2.0
# 5           2.0                 no                     0.0
#
#    Screen_Time_Duration            Travel_Mode       Obesity_level
# 0                   1.0  Public_Transportation       Normal_Weight
# 1                   0.0  Public_Transportation       Normal_Weight
# 2                   1.0  Public_Transportation       Normal_Weight
# 3                   0.0                Walking  Overweight_Level_I
# 5                   0.0             Automobile       Normal_Weight

# %% [markdown]
# # **Mapping all the categroical columns**

# %%
#Oridnal encoding on the following columns
df_new['Smoking_Habit']=df_new['Smoking_Habit'].map({'no':0,'yes':1})
df_new['Calorie_Monitoring']=df_new['Calorie_Monitoring'].map({'no':0,'yes':1})
df_new['Obesity_level']=df_new['Obesity_level'].map({
    'Insufficient_Weight':1,
    'Normal_Weight':2,
    'Overweight_Level_I':3,
    'Overweight_Level_II':4,
    'Obesity_Type_I':5,
   'Obesity_Type_II':6,
    'Obesity_Type_III':7,
    'Obesity_Type_IV':8})

# %%
#checking the mapped dataframe
df_new.head()
# Out:
#     Age  Height  Weight  Eat_Vegetables  Meal_count  Smoking_Habit  \
# 0  21.0    1.62    64.0             2.0         3.0              0
# 1  21.0    1.52    56.0             3.0         3.0              1
# 2  23.0    1.80    77.0             2.0         3.0              0
# 3  27.0    1.80    87.0             3.0         3.0              0
# 5  29.0    1.62    53.0             2.0         3.0              0
#
#    Water_intake  Calorie_Monitoring  physical_activity_freq  \
# 0           2.0                   0                     0.0
# 1           3.0                   1                     3.0
# 2           2.0                   0                     2.0
# 3           2.0                   0                     2.0
# 5           2.0                   0                     0.0
#
#    Screen_Time_Duration            Travel_Mode  Obesity_level
# 0                   1.0  Public_Transportation              2
# 1                   0.0  Public_Transportation              2
# 2                   1.0  Public_Transportation              2
# 3                   0.0                Walking              3
# 5                   0.0             Automobile              2

# %%
#onehot encoding on the travel_mode column as it doesnt have any order
df_new = pd.get_dummies(df_new, columns=['Travel_Mode'], prefix=['Travel_Mode']).apply(lambda x: x.astype(int))
df_new.head()
# Out:
#    Age  Height  Weight  Eat_Vegetables  Meal_count  Smoking_Habit  \
# 0   21       1      64               2           3              0
# 1   21       1      56               3           3              1
# 2   23       1      77               2           3              0
# 3   27       1      87               3           3              0
# 5   29       1      53               2           3              0
#
#    Water_intake  Calorie_Monitoring  physical_activity_freq  \
# 0             2                   0                       0
# 1             3                   1                       3
# 2             2                   0                       2
# 3             2                   0                       2
# 5             2                   0                       0
#
#    Screen_Time_Duration  Obesity_level  Travel_Mode_Automobile  \
# 0                     1              2                       0
# 1                     0              2                       0
# 2                     1              2                       0
# 3                     0              3                       0
# 5                     0              2                       1
#
#    Travel_Mode_Bike  Travel_Mode_Motorbike  Travel_Mode_Public_Transportation  \
# 0                 0                      0                                  1
# 1                 0                      0                                  1
# 2                 0                      0                                  1
# 3                 0                      0                                  0
# 5                 0                      0                                  0
#
#    Travel_Mode_Walking
# 0                    0
# 1                    0
# 2                    0
# 3                    1
# 5                    0

# %% [markdown]
# ## **Train Test Split**

# %%
from sklearn.model_selection import train_test_split
x=df_new.drop('Obesity_level',axis=1)
y=df_new['Obesity_level']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
print("x_train: {}".format(x_train.shape))
print("x_test: {}".format(x_test.shape))
print("y_train: {}".format(y_train.shape))
print("y_test: {}" .format(y_test.shape))
# Out:
# x_train: (986, 15)
# x_test: (423, 15)
# y_train: (986,)
# y_test: (423,)

# %% [markdown]
# ## Applying all the classification model and checking the performance of the model
# (WEIGHTED F1 SCORE)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# # KNN CLASSIFIER

# %%
#importing necessary libraries for KNN
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(x_train,y_train)
y_pred=knn.predict(x_test)
F1KNN=f1_score(y_test, y_pred, average='weighted')
print('f1 score is: ', f1_score(y_test, y_pred, average='weighted'))
print('-'*100)
print(classification_report(y_test,y_pred))
# Out:
# f1 score is:  0.8364758198465699
# ----------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            1       0.74      1.00      0.85        46
#            2       0.69      0.47      0.56        53
#            3       0.70      0.67      0.68        45
#            4       0.81      0.71      0.76        59
#            5       0.80      0.91      0.85        54
#            6       0.97      0.99      0.98        70
#            7       0.98      1.00      0.99        96
#
#     accuracy                           0.84       423
#    macro avg       0.81      0.82      0.81       423
# weighted avg       0.84      0.84      0.84       423

# %% [markdown]
# # DECISION TREE CLASSIFIER

# %%
#importing neccessary librariesd for  DecisionTreeClassifier
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier()
dtree.fit(x_train,y_train)
y_pred = dtree.predict(x_test)
F1DT=f1_score(y_test, y_pred, average='weighted')
print('f1 score is: ', f1_score(y_test, y_pred, average='weighted'))
print('-'*100)
print(classification_report(y_test,y_pred))
# Out:
# f1 score is:  0.8514047130540738
# ----------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            1       0.79      0.96      0.86        46
#            2       0.76      0.53      0.62        53
#            3       0.70      0.67      0.68        45
#            4       0.77      0.81      0.79        59
#            5       0.80      0.91      0.85        54
#            6       0.99      0.96      0.97        70
#            7       1.00      1.00      1.00        96
#
#     accuracy                           0.86       423
#    macro avg       0.83      0.83      0.83       423
# weighted avg       0.86      0.86      0.85       423

# %%
from sklearn.linear_model import LogisticRegression


logreg = LogisticRegression()

logreg.fit(x_train, y_train)
y_pred = logreg.predict(x_test)

# Calculate and print the F1 score
f1_logreg = f1_score(y_test, y_pred, average='weighted')
print('F1 score for Logistic Regression:', f1_logreg)

# Print the classification report
print('\nClassification Report for Logistic Regression:\n', classification_report(y_test, y_pred))
# Out:
# F1 score for Logistic Regression: 0.6715994827342344
#
# Classification Report for Logistic Regression:
#                precision    recall  f1-score   support
#
#            1       0.70      0.83      0.76        46
#            2       0.60      0.53      0.56        53
#            3       0.48      0.29      0.36        45
#            4       0.55      0.37      0.44        59
#            5       0.48      0.56      0.51        54
#            6       0.81      0.93      0.87        70
#            7       0.86      1.00      0.92        96
#
#     accuracy                           0.69       423
#    macro avg       0.64      0.64      0.63       423
# weighted avg       0.67      0.69      0.67       423

# %% [markdown]
# ## Support Vector Classifier(SVC)

# %%
#importing necesary libraries for Support Vector Classification (SVC)
#from sklearn.svm import SVC
#svc = SVC()
#svc.fit(x_train,y_train)
#y_pred = svc.predict(x_test)
#F1SVC=f1_score(y_test, y_pred, average='weighted')
#print('f1 score is: ', f1_score(y_test, y_pred, average='weighted'))
#print('-'*100)
#print(classification_report(y_test,y_pred))

# %% [markdown]
# ##NAIVE BAYES CLASSIFIER - BERNOULLI NB

# %%
#importing necessary libraries for BERNOULLI NB
from  sklearn.naive_bayes import BernoulliNB
bnb = BernoulliNB()
bnb.fit(x_train, y_train)
y_pred = bnb.predict(x_test)
F1BNB=f1_score(y_test, y_pred, average='weighted')
print('f1 score is: ', f1_score(y_test, y_pred, average='weighted'))
print('-'*100)
print(classification_report(y_test,y_pred))
# Out:
# f1 score is:  0.28949615063200335
# ----------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            1       0.42      0.11      0.17        46
#            2       0.28      0.43      0.34        53
#            3       0.28      0.11      0.16        45
#            4       0.00      0.00      0.00        59
#            5       0.19      0.15      0.16        54
#            6       0.48      0.29      0.36        70
#            7       0.41      0.97      0.58        96
#
#     accuracy                           0.36       423
#    macro avg       0.29      0.29      0.25       423
# weighted avg       0.31      0.36      0.29       423

# %% [markdown]
# ##NAIVE BAYES CLASSIFIER - Gaussian NB

# %%
#importing necessary libraries for Gaussian NB
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(x_train, y_train)
y_pred = gnb.predict(x_test)
F1GNB=f1_score(y_test, y_pred, average='weighted')
print('f1 score is: ', f1_score(y_test, y_pred, average='weighted'))
print('-' * 100)
print(classification_report(y_test, y_pred))
# Out:
# f1 score is:  0.46903727549564106
# ----------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            1       0.61      0.80      0.69        46
#            2       0.64      0.17      0.27        53
#            3       0.29      0.04      0.08        45
#            4       0.00      0.00      0.00        59
#            5       0.25      0.87      0.39        54
#            6       0.94      0.46      0.62        70
#            7       0.80      0.99      0.88        96
#
#     accuracy                           0.52       423
#    macro avg       0.50      0.48      0.42       423
# weighted avg       0.55      0.52      0.47       423

# %% [markdown]
# # Random Forest Classifier

# %%
#importing neccessary libraries  for  RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(x_train,y_train)
y_pred = rfc.predict(x_test)
F1RFC=f1_score(y_test, y_pred, average='weighted')
print('f1 score is: ', f1_score(y_test, y_pred, average='weighted'))
print('-'*100)
print(classification_report(y_test,y_pred))
# Out:
# f1 score is:  0.8637191510709652
# ----------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            1       0.82      0.98      0.89        46
#            2       0.78      0.68      0.73        53
#            3       0.64      0.71      0.67        45
#            4       0.80      0.68      0.73        59
#            5       0.84      0.89      0.86        54
#            6       1.00      0.99      0.99        70
#            7       1.00      1.00      1.00        96
#
#     accuracy                           0.87       423
#    macro avg       0.84      0.85      0.84       423
# weighted avg       0.87      0.87      0.86       423

# %% [markdown]
# ## GRADIENT BOOSTING

# %%
#importing neccessary libraries for  GRADIENT BOOSTING
from sklearn.ensemble import GradientBoostingClassifier
gb_classifier = GradientBoostingClassifier()
gb_classifier.fit(x_train, y_train)
y_pred = gb_classifier.predict(x_test)
F1GB=f1_score(y_test, y_pred, average='weighted')
print('f1 score is: ', f1_score(y_test, y_pred, average='weighted'))
print('-' * 100)
print(classification_report(y_test, y_pred))
# Out:
# f1 score is:  0.8775566086605123
# ----------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            1       0.81      0.96      0.88        46
#            2       0.79      0.72      0.75        53
#            3       0.80      0.73      0.77        45
#            4       0.79      0.71      0.75        59
#            5       0.81      0.96      0.88        54
#            6       1.00      0.96      0.98        70
#            7       1.00      1.00      1.00        96
#
#     accuracy                           0.88       423
#    macro avg       0.86      0.86      0.86       423
# weighted avg       0.88      0.88      0.88       423

# %% [markdown]
# ##ADABOOST

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import f1_score


ada_classifier = AdaBoostClassifier()


ada_classifier.fit(x_train, y_train)


y_pred = ada_classifier.predict(x_test)
F1ADA=f1_score(y_test, y_pred, average='weighted')

print('f1 score is: ', f1_score(y_test, y_pred, average='weighted'))
print('-' * 100)
print(classification_report(y_test, y_pred))
# Out:
# f1 score is:  0.32825989196452277
# ----------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            1       0.63      1.00      0.77        46
#            2       0.43      0.43      0.43        53
#            3       0.00      0.00      0.00        45
#            4       0.47      0.85      0.61        59
#            5       0.67      0.07      0.13        54
#            6       0.37      0.97      0.53        70
#            7       0.00      0.00      0.00        96
#
#     accuracy                           0.45       423
#    macro avg       0.37      0.48      0.35       423
# weighted avg       0.33      0.45      0.33       423

# %% [markdown]
# ##F1 scores from different models

# %%
model_data = {
    'Model': ['KNN', 'Decision Tree', #'SVC',
              'Bernoulli NB', 'Gaussian NB', 'Random Forest', 'Gradient Boosting', 'AdaBoost','Logistic Regression'],
    'F1 Score': [F1KNN,F1DT,#F1SVC,
                 F1BNB,F1GNB,F1RFC,F1GB,F1ADA,f1_logreg]
}


model_df = pd.DataFrame(model_data)
model_df=model_df.sort_values(by='F1 Score', ascending=False)

# %%
plt.figure(figsize=(12, 10

                    ))
ax = sns.barplot(x='Model', y='F1 Score', data=model_df, palette='viridis')
plt.title('Model Performance (F1 Score)')
plt.xlabel('Model')
plt.ylabel('F1 Score')
plt.xticks(rotation=45)

# Add value labels on top of the bars
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'),
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha = 'center', va = 'center',
                xytext = (0, 9),
                textcoords = 'offset points')

plt.show()

# %%
! pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.0.0-py3-none-any.whl.metadata (16 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.14.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.36)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.6)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.2)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Downloading optuna-4.0.0-py3-none-any.whl (362 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.8/362.8 kB 7.8 MB/s eta 0:00:00
# Downloading alembic-1.14.0-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.5/233.5 kB 4.6 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading Mako-1.3.6-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 310.6 kB/s eta 0:00:00
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.6 alembic-1.14.0 colorlog-6.9.0 optuna-4.0.0

# %%
import optuna
def objective(trial):
    # Define the hyperparameters to optimize
    if trial.suggest_categorical ('model', ['GradientBoosting', 'RandomForestClassifier', 'DecisionTree', 'KNN']):
       # Decision Tree
      max_depth = trial.suggest_int('max_depth', 3, 10)
      min_samples_split = trial.suggest_int('min_samples_split', 2, 10)
      min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 4)

      model = DecisionTreeClassifier(
          max_depth=max_depth,
          min_samples_split=min_samples_split,
          min_samples_leaf=min_samples_leaf,
          random_state=0)
    elif trial.suggest_categorical('model', ['GradientBoosting', 'RandomForestClassifier', 'DecisionTree','KNN']):
      #randomforest
      n_estimators = trial.suggest_int('n_estimators', 100, 1000)
      max_depth = trial.suggest_int('max_depth', 3, 10)
      min_samples_split = trial.suggest_int('min_samples_split', 2, 10)
      min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 4)

      model = RandomForestClassifier (
          n_estimators=n_estimators,
          max_depth=max_depth,
          min_samples_split=min_samples_split,
          min_samples_leaf=min_samples_leaf,
      )
    elif trial.suggest_categorical('model', ['GradientBoosting', 'RandomForestClassifier', 'DecisionTree','KNN']):
      #Gradient Boosting

        n_estimators = trial.suggest_int('n_estimators', 100, 1000)
        max_depth = trial.suggest_int('max_depth', 3, 10)
        learning_rate = trial.suggest_float('learning_rate', 0.01, 0.3, log=True)
        subsample = trial.suggest_float('subsample', 0.5, 1.0)

        model = GradientBoostingClassifier(
            n_estimators=n_estimators,
            max_depth=max_depth,
            learning_rate=learning_rate,
            subsample=subsample,
            random_state=0
        )
    else:
        # K-Nearest Neighbors Classifier
        n_neighbors = trial.suggest_int('n_neighbors', 1, 20)
        weights = trial.suggest_categorical('weights', ['uniform', 'distance'])
        p = trial.suggest_int('p', 1, 2)
        model = KNeighborsClassifier(
            n_neighbors=n_neighbors,
            weights=weights,
            p=p
        )


    return model.fit(x_train, y_train).score(x_test, y_test)

study = optuna.create_study(sampler=optuna.samplers.TPESampler(),direction='maximize')
study.optimize(objective, n_trials=200)
# Out:
# [I 2024-11-10 11:29:10,089] A new study created in memory with name: no-name-704c4127-cebd-4117-8099-0f48bedfcf7b
# [I 2024-11-10 11:29:10,118] Trial 0 finished with value: 0.8439716312056738 and parameters: {'model': 'DecisionTree', 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:10,180] Trial 1 finished with value: 0.7825059101654847 and parameters: {'model': 'KNN', 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 4}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:10,234] Trial 2 finished with value: 0.8156028368794326 and parameters: {'model': 'KNN', 'max_depth': 6, 'min_samples_split': 9, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:10,281] Trial 3 finished with value: 0.806146572104019 and parameters: {'model': 'DecisionTree', 'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 4}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:10,338] Trial 4 finished with value: 0.8392434988179669 and parameters: {'model': 'DecisionTree', 'max_depth': 9, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:10,385] Trial 5 finished with value: 0.83451536643026 and parameters: {'model': 'DecisionTree', 'max_depth': 10, 'min_samples_split': 7, 'min_samples_leaf': 2}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:10,426] Trial 6 finished with value: 0.8226950354609929 and parameters: {'model': 'DecisionTree', 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 2}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:10,462] Trial 7 finished with value: 0.8297872340425532 and parameters: {'model': 'DecisionTree', 'max_depth': 8, 'min_samples_split': 6, 'min_samples_leaf': 2}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:10,487] Trial 8 finished with value: 0.8037825059101655 and parameters: {'model': 'GradientBoosting', 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:10,510] Trial 9 finished with value: 0.8297872340425532 and parameters: {'model': 'GradientBoosting', 'max_depth': 8, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:10,561] Trial 10 finished with value: 0.8297872340425532 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 3}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:10,656] Trial 11 finished with value: 0.8392434988179669 and parameters: {'model': 'DecisionTree', 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:10,776] Trial 12 finished with value: 0.83451536643026 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 3}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:10,845] Trial 13 finished with value: 0.8392434988179669 and parameters: {'model': 'DecisionTree', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 3}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:10,903] Trial 14 finished with value: 0.7399527186761229 and parameters: {'model': 'DecisionTree', 'max_depth': 3, 'min_samples_split': 6, 'min_samples_leaf': 2}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:10,949] Trial 15 finished with value: 0.8156028368794326 and parameters: {'model': 'DecisionTree', 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 4}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:11,014] Trial 16 finished with value: 0.8297872340425532 and parameters: {'model': 'KNN', 'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:11,059] Trial 17 finished with value: 0.8439716312056738 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 2}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:11,106] Trial 18 finished with value: 0.8132387706855791 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 6, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:11,159] Trial 19 finished with value: 0.8392434988179669 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 2}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:11,206] Trial 20 finished with value: 0.8226950354609929 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 8, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:11,261] Trial 21 finished with value: 0.8392434988179669 and parameters: {'model': 'GradientBoosting', 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:11,314] Trial 22 finished with value: 0.83451536643026 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 6, 'min_samples_leaf': 2}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:11,362] Trial 23 finished with value: 0.83451536643026 and parameters: {'model': 'DecisionTree', 'max_depth': 10, 'min_samples_split': 3, 'min_samples_leaf': 3}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:11,411] Trial 24 finished with value: 0.8274231678486997 and parameters: {'model': 'DecisionTree', 'max_depth': 7, 'min_samples_split': 4, 'min_samples_leaf': 2}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:11,466] Trial 25 finished with value: 0.83451536643026 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 8, 'min_samples_leaf': 3}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:11,519] Trial 26 finished with value: 0.8297872340425532 and parameters: {'model': 'KNN', 'max_depth': 8, 'min_samples_split': 6, 'min_samples_leaf': 2}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:11,577] Trial 27 finished with value: 0.8439716312056738 and parameters: {'model': 'GradientBoosting', 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:11,625] Trial 28 finished with value: 0.8439716312056738 and parameters: {'model': 'GradientBoosting', 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:11,659] Trial 29 finished with value: 0.8416075650118203 and parameters: {'model': 'GradientBoosting', 'max_depth': 10, 'min_samples_split': 3, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:11,698] Trial 30 finished with value: 0.8037825059101655 and parameters: {'model': 'GradientBoosting', 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:11,737] Trial 31 finished with value: 0.8439716312056738 and parameters: {'model': 'GradientBoosting', 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:11,779] Trial 32 finished with value: 0.8439716312056738 and parameters: {'model': 'GradientBoosting', 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:11,821] Trial 33 finished with value: 0.83451536643026 and parameters: {'model': 'GradientBoosting', 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:11,858] Trial 34 finished with value: 0.8439716312056738 and parameters: {'model': 'KNN', 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:11,894] Trial 35 finished with value: 0.8439716312056738 and parameters: {'model': 'GradientBoosting', 'max_depth': 9, 'min_samples_split': 3, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:11,937] Trial 36 finished with value: 0.83451536643026 and parameters: {'model': 'GradientBoosting', 'max_depth': 10, 'min_samples_split': 7, 'min_samples_leaf': 2}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:11,993] Trial 37 finished with value: 0.8368794326241135 and parameters: {'model': 'GradientBoosting', 'max_depth': 10, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:12,052] Trial 38 finished with value: 0.806146572104019 and parameters: {'model': 'KNN', 'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 4}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:12,140] Trial 39 finished with value: 0.8274231678486997 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 8, 'min_samples_split': 4, 'min_samples_leaf': 2}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:12,232] Trial 40 finished with value: 0.8392434988179669 and parameters: {'model': 'GradientBoosting', 'max_depth': 9, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:12,319] Trial 41 finished with value: 0.8439716312056738 and parameters: {'model': 'GradientBoosting', 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:12,402] Trial 42 finished with value: 0.8368794326241135 and parameters: {'model': 'GradientBoosting', 'max_depth': 10, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:12,447] Trial 43 finished with value: 0.8439716312056738 and parameters: {'model': 'GradientBoosting', 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:12,484] Trial 44 finished with value: 0.83451536643026 and parameters: {'model': 'GradientBoosting', 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:12,530] Trial 45 finished with value: 0.8439716312056738 and parameters: {'model': 'GradientBoosting', 'max_depth': 9, 'min_samples_split': 3, 'min_samples_leaf': 2}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:12,570] Trial 46 finished with value: 0.7825059101654847 and parameters: {'model': 'DecisionTree', 'max_depth': 4, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:12,608] Trial 47 finished with value: 0.83451536643026 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:12,648] Trial 48 finished with value: 0.8321513002364066 and parameters: {'model': 'DecisionTree', 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 2}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:12,684] Trial 49 finished with value: 0.8297872340425532 and parameters: {'model': 'GradientBoosting', 'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:12,727] Trial 50 finished with value: 0.8392434988179669 and parameters: {'model': 'DecisionTree', 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 2}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:12,763] Trial 51 finished with value: 0.8439716312056738 and parameters: {'model': 'GradientBoosting', 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:12,803] Trial 52 finished with value: 0.8439716312056738 and parameters: {'model': 'GradientBoosting', 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:12,842] Trial 53 finished with value: 0.8368794326241135 and parameters: {'model': 'GradientBoosting', 'max_depth': 10, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:12,878] Trial 54 finished with value: 0.8439716312056738 and parameters: {'model': 'GradientBoosting', 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:12,928] Trial 55 finished with value: 0.8416075650118203 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:13,025] Trial 56 finished with value: 0.8297872340425532 and parameters: {'model': 'GradientBoosting', 'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:13,134] Trial 57 finished with value: 0.83451536643026 and parameters: {'model': 'KNN', 'max_depth': 9, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:13,217] Trial 58 finished with value: 0.8392434988179669 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 2}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:13,302] Trial 59 finished with value: 0.8132387706855791 and parameters: {'model': 'DecisionTree', 'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:13,402] Trial 60 finished with value: 0.8014184397163121 and parameters: {'model': 'GradientBoosting', 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 2}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:13,482] Trial 61 finished with value: 0.8439716312056738 and parameters: {'model': 'KNN', 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:13,555] Trial 62 finished with value: 0.8439716312056738 and parameters: {'model': 'KNN', 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:13,624] Trial 63 finished with value: 0.83451536643026 and parameters: {'model': 'KNN', 'max_depth': 9, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:13,696] Trial 64 finished with value: 0.83451536643026 and parameters: {'model': 'KNN', 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:13,835] Trial 65 finished with value: 0.8321513002364066 and parameters: {'model': 'KNN', 'max_depth': 8, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:13,951] Trial 66 finished with value: 0.8368794326241135 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 10, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:14,123] Trial 67 finished with value: 0.8156028368794326 and parameters: {'model': 'DecisionTree', 'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 4}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:14,289] Trial 68 finished with value: 0.8321513002364066 and parameters: {'model': 'GradientBoosting', 'max_depth': 8, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:14,390] Trial 69 finished with value: 0.8416075650118203 and parameters: {'model': 'GradientBoosting', 'max_depth': 10, 'min_samples_split': 3, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:14,539] Trial 70 finished with value: 0.8416075650118203 and parameters: {'model': 'KNN', 'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:14,814] Trial 71 finished with value: 0.8416075650118203 and parameters: {'model': 'GradientBoosting', 'max_depth': 10, 'min_samples_split': 3, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:14,895] Trial 72 finished with value: 0.8439716312056738 and parameters: {'model': 'GradientBoosting', 'max_depth': 9, 'min_samples_split': 3, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:15,102] Trial 73 finished with value: 0.8274231678486997 and parameters: {'model': 'GradientBoosting', 'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:15,256] Trial 74 finished with value: 0.8416075650118203 and parameters: {'model': 'GradientBoosting', 'max_depth': 10, 'min_samples_split': 3, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.8439716312056738.
# [I 2024-11-10 11:29:15,404] Trial 75 finished with value: 0.8463356973995272 and parameters: {'model': 'GradientBoosting', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:15,617] Trial 76 finished with value: 0.83451536643026 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:15,767] Trial 77 finished with value: 0.8392434988179669 and parameters: {'model': 'GradientBoosting', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 2}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:15,879] Trial 78 finished with value: 0.7399527186761229 and parameters: {'model': 'DecisionTree', 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:15,980] Trial 79 finished with value: 0.8226950354609929 and parameters: {'model': 'GradientBoosting', 'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 3}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:16,169] Trial 80 finished with value: 0.8297872340425532 and parameters: {'model': 'GradientBoosting', 'max_depth': 10, 'min_samples_split': 9, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:16,389] Trial 81 finished with value: 0.8156028368794326 and parameters: {'model': 'GradientBoosting', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:16,497] Trial 82 finished with value: 0.8439716312056738 and parameters: {'model': 'GradientBoosting', 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:16,587] Trial 83 finished with value: 0.8416075650118203 and parameters: {'model': 'GradientBoosting', 'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:16,740] Trial 84 finished with value: 0.8439716312056738 and parameters: {'model': 'GradientBoosting', 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:16,870] Trial 85 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:17,089] Trial 86 finished with value: 0.8439716312056738 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:17,231] Trial 87 finished with value: 0.83451536643026 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:17,380] Trial 88 finished with value: 0.8392434988179669 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 2}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:17,639] Trial 89 finished with value: 0.8439716312056738 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:17,825] Trial 90 finished with value: 0.8416075650118203 and parameters: {'model': 'DecisionTree', 'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:17,931] Trial 91 finished with value: 0.8439716312056738 and parameters: {'model': 'GradientBoosting', 'max_depth': 9, 'min_samples_split': 3, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:18,086] Trial 92 finished with value: 0.8156028368794326 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:18,266] Trial 93 finished with value: 0.8439716312056738 and parameters: {'model': 'GradientBoosting', 'max_depth': 9, 'min_samples_split': 3, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:18,378] Trial 94 finished with value: 0.8439716312056738 and parameters: {'model': 'GradientBoosting', 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:18,466] Trial 95 finished with value: 0.7825059101654847 and parameters: {'model': 'KNN', 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:18,683] Trial 96 finished with value: 0.8392434988179669 and parameters: {'model': 'DecisionTree', 'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 3}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:18,801] Trial 97 finished with value: 0.8416075650118203 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 10, 'min_samples_split': 3, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:18,961] Trial 98 finished with value: 0.8439716312056738 and parameters: {'model': 'GradientBoosting', 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:19,145] Trial 99 finished with value: 0.8416075650118203 and parameters: {'model': 'GradientBoosting', 'max_depth': 10, 'min_samples_split': 3, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:19,292] Trial 100 finished with value: 0.8274231678486997 and parameters: {'model': 'KNN', 'max_depth': 8, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:19,568] Trial 101 finished with value: 0.8439716312056738 and parameters: {'model': 'GradientBoosting', 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:19,738] Trial 102 finished with value: 0.8439716312056738 and parameters: {'model': 'GradientBoosting', 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:19,866] Trial 103 finished with value: 0.8439716312056738 and parameters: {'model': 'GradientBoosting', 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:19,989] Trial 104 finished with value: 0.83451536643026 and parameters: {'model': 'GradientBoosting', 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:20,151] Trial 105 finished with value: 0.8416075650118203 and parameters: {'model': 'GradientBoosting', 'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:20,259] Trial 106 finished with value: 0.8037825059101655 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 5, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:20,365] Trial 107 finished with value: 0.8439716312056738 and parameters: {'model': 'DecisionTree', 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:20,490] Trial 108 finished with value: 0.8439716312056738 and parameters: {'model': 'GradientBoosting', 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:20,697] Trial 109 finished with value: 0.8392434988179669 and parameters: {'model': 'GradientBoosting', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 2}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:20,910] Trial 110 finished with value: 0.8439716312056738 and parameters: {'model': 'KNN', 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:21,083] Trial 111 finished with value: 0.8439716312056738 and parameters: {'model': 'GradientBoosting', 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:21,256] Trial 112 finished with value: 0.8439716312056738 and parameters: {'model': 'GradientBoosting', 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:21,394] Trial 113 finished with value: 0.83451536643026 and parameters: {'model': 'GradientBoosting', 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:21,517] Trial 114 finished with value: 0.8368794326241135 and parameters: {'model': 'GradientBoosting', 'max_depth': 10, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:21,650] Trial 115 finished with value: 0.8274231678486997 and parameters: {'model': 'GradientBoosting', 'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:21,727] Trial 116 finished with value: 0.8439716312056738 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:21,880] Trial 117 finished with value: 0.8439716312056738 and parameters: {'model': 'GradientBoosting', 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:21,974] Trial 118 finished with value: 0.83451536643026 and parameters: {'model': 'DecisionTree', 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:22,054] Trial 119 finished with value: 0.8392434988179669 and parameters: {'model': 'GradientBoosting', 'max_depth': 9, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:22,188] Trial 120 finished with value: 0.8439716312056738 and parameters: {'model': 'GradientBoosting', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:22,298] Trial 121 finished with value: 0.8439716312056738 and parameters: {'model': 'GradientBoosting', 'max_depth': 9, 'min_samples_split': 3, 'min_samples_leaf': 2}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:22,400] Trial 122 finished with value: 0.8439716312056738 and parameters: {'model': 'GradientBoosting', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 2}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:22,498] Trial 123 finished with value: 0.8439716312056738 and parameters: {'model': 'GradientBoosting', 'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 2}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:22,595] Trial 124 finished with value: 0.8439716312056738 and parameters: {'model': 'GradientBoosting', 'max_depth': 9, 'min_samples_split': 3, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:22,656] Trial 125 finished with value: 0.8132387706855791 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 4}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:22,716] Trial 126 finished with value: 0.8274231678486997 and parameters: {'model': 'KNN', 'max_depth': 8, 'min_samples_split': 3, 'min_samples_leaf': 2}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:22,777] Trial 127 finished with value: 0.83451536643026 and parameters: {'model': 'GradientBoosting', 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:22,862] Trial 128 finished with value: 0.8439716312056738 and parameters: {'model': 'GradientBoosting', 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:22,980] Trial 129 finished with value: 0.8439716312056738 and parameters: {'model': 'DecisionTree', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:23,107] Trial 130 finished with value: 0.83451536643026 and parameters: {'model': 'GradientBoosting', 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 2}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:23,219] Trial 131 finished with value: 0.8439716312056738 and parameters: {'model': 'GradientBoosting', 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:23,301] Trial 132 finished with value: 0.8439716312056738 and parameters: {'model': 'GradientBoosting', 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:23,393] Trial 133 finished with value: 0.8439716312056738 and parameters: {'model': 'GradientBoosting', 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:23,481] Trial 134 finished with value: 0.8439716312056738 and parameters: {'model': 'GradientBoosting', 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:23,555] Trial 135 finished with value: 0.8368794326241135 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 10, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:23,653] Trial 136 finished with value: 0.8416075650118203 and parameters: {'model': 'GradientBoosting', 'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:23,770] Trial 137 finished with value: 0.8439716312056738 and parameters: {'model': 'KNN', 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:23,877] Trial 138 finished with value: 0.83451536643026 and parameters: {'model': 'GradientBoosting', 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:23,977] Trial 139 finished with value: 0.8463356973995272 and parameters: {'model': 'GradientBoosting', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:24,109] Trial 140 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:24,203] Trial 141 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:24,269] Trial 142 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:24,332] Trial 143 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:24,438] Trial 144 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:24,518] Trial 145 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:24,608] Trial 146 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:24,755] Trial 147 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:24,850] Trial 148 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:24,909] Trial 149 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:25,035] Trial 150 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:25,131] Trial 151 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:25,192] Trial 152 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:25,261] Trial 153 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:25,666] Trial 154 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:25,786] Trial 155 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:25,854] Trial 156 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:25,922] Trial 157 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:25,995] Trial 158 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:26,090] Trial 159 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:26,152] Trial 160 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:26,222] Trial 161 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:26,298] Trial 162 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:26,538] Trial 163 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:26,700] Trial 164 finished with value: 0.8156028368794326 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:26,789] Trial 165 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:26,952] Trial 166 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:27,080] Trial 167 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:27,169] Trial 168 finished with value: 0.8156028368794326 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:27,285] Trial 169 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:27,358] Trial 170 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:27,435] Trial 171 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:27,503] Trial 172 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:27,697] Trial 173 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:27,872] Trial 174 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:28,019] Trial 175 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:28,097] Trial 176 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:28,156] Trial 177 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:28,219] Trial 178 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:28,278] Trial 179 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:28,463] Trial 180 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:28,577] Trial 181 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:28,672] Trial 182 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:28,832] Trial 183 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:28,955] Trial 184 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:29,135] Trial 185 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:29,326] Trial 186 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:29,504] Trial 187 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:29,682] Trial 188 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:29,773] Trial 189 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:29,985] Trial 190 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:30,136] Trial 191 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:30,308] Trial 192 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:30,379] Trial 193 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:30,555] Trial 194 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:30,631] Trial 195 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:30,765] Trial 196 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:30,900] Trial 197 finished with value: 0.8156028368794326 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:31,024] Trial 198 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.
# [I 2024-11-10 11:29:31,115] Trial 199 finished with value: 0.8463356973995272 and parameters: {'model': 'RandomForestClassifier', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 75 with value: 0.8463356973995272.

# %%
print('Best parameters:', study.best_params)
print('Best f1_score:', study.best_value)
# Out:
# Best parameters: {'model': 'GradientBoosting', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1}
# Best f1_score: 0.8463356973995272

# %%
import joblib

# %%
gb_classifier = GradientBoostingClassifier()
gb_classifier.fit(x_train, y_train)


joblib.dump(gb_classifier, 'GradientBoosting.joblib')


loaded_model = joblib.load('GradientBoosting.joblib')


predictions = loaded_model.predict(x_test)
predictions
# Out:
# array([1, 5, 7, 2, 5, 3, 4, 2, 6, 3, 2, 5, 6, 6, 1, 5, 5, 4, 7, 4, 1, 5,
#        3, 2, 7, 5, 7, 6, 5, 4, 1, 7, 6, 7, 1, 4, 4, 3, 3, 3, 7, 7, 6, 1,
#        7, 1, 2, 7, 6, 3, 7, 5, 6, 1, 5, 5, 6, 5, 5, 5, 4, 5, 7, 6, 7, 3,
#        5, 2, 4, 4, 5, 2, 2, 6, 1, 5, 1, 2, 6, 4, 3, 5, 2, 2, 5, 5, 6, 7,
#        1, 1, 4, 4, 1, 3, 7, 5, 5, 7, 4, 1, 7, 2, 3, 7, 1, 6, 6, 7, 1, 4,
#        1, 5, 5, 1, 1, 2, 1, 2, 6, 5, 4, 6, 7, 3, 5, 7, 7, 7, 2, 1, 4, 4,
#        7, 4, 6, 4, 2, 6, 7, 1, 6, 2, 4, 3, 2, 7, 3, 7, 4, 6, 7, 5, 4, 5,
#        5, 6, 4, 1, 7, 7, 5, 5, 5, 7, 7, 2, 4, 4, 7, 6, 3, 3, 7, 1, 4, 7,
#        6, 4, 7, 3, 7, 3, 4, 4, 6, 7, 5, 6, 5, 7, 7, 6, 7, 5, 6, 7, 4, 2,
#        1, 2, 7, 5, 7, 1, 6, 5, 6, 2, 7, 6, 7, 4, 7, 5, 2, 3, 1, 5, 7, 3,
#        1, 1, 7, 2, 6, 6, 6, 3, 7, 6, 7, 6, 6, 6, 1, 7, 5, 5, 4, 4, 7, 2,
#        1, 7, 2, 5, 3, 4, 7, 3, 3, 5, 6, 4, 6, 4, 7, 7, 3, 1, 7, 4, 4, 4,
#        7, 2, 1, 2, 7, 6, 5, 7, 2, 2, 7, 5, 5, 6, 4, 2, 1, 6, 6, 4, 7, 1,
#        2, 4, 6, 6, 6, 4, 6, 6, 6, 2, 7, 3, 7, 5, 7, 7, 7, 2, 3, 3, 3, 1,
#        6, 6, 4, 5, 5, 7, 7, 1, 5, 4, 6, 2, 5, 3, 5, 6, 6, 1, 7, 3, 6, 7,
#        4, 2, 7, 4, 7, 1, 5, 7, 6, 2, 7, 1, 3, 2, 6, 3, 6, 5, 6, 1, 4, 2,
#        3, 5, 7, 5, 4, 2, 6, 5, 2, 7, 3, 4, 7, 5, 4, 3, 1, 7, 7, 1, 7, 2,
#        6, 1, 7, 7, 4, 3, 7, 4, 7, 3, 7, 7, 7, 1, 6, 3, 5, 6, 7, 5, 5, 3,
#        6, 7, 3, 2, 3, 4, 1, 1, 1, 6, 6, 7, 4, 1, 1, 3, 5, 7, 7, 7, 5, 4,
#        1, 3, 1, 2, 7])

# %%
feature_importances = pd.Series(gb_classifier.feature_importances_, index=x_train.columns)
feature_importances.nlargest(10).plot(kind='barh')
plt.title('Top 10 Feature Importances (Gradient Boosting)')
plt.xlabel('Feature Importance')
plt.ylabel('Features')
plt.show()

# %% [markdown]
# ## My top 5 important features based on feature importance from Random Forest:
# 1. Weight
# 2. Eat vegetables
# 3. Age
# 4. Meal count
# 5. Physical activity frequency
# 6.Water intake
